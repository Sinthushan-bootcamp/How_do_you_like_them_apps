# %% [markdown]
# # Budget Analysis
#
# ---
#
# ## Environment Setup

# %%
# Initial Imports
import os
import plaid
import requests
import datetime
import json
import pandas as pd
from dotenv import load_dotenv

# %matplotlib inline

# %%
# Helper functions

def pretty_print_response(response):
    """
    This function formats a JSON file to pretty printing it in the screen.
    """
    print(json.dumps(response, indent=4, sort_keys=True))

# %%
# Set environment variables from the .env file
load_dotenv()
# Out:
# True

# %%
# Extract API keys from environment variables
PLAID_CLIENT_ID = os.getenv("PLAID_CLIENT_ID")
PLAID_SECRET = os.getenv("PLAID_SECRET")
PLAID_PUBLIC_KEY = os.getenv("PLAID_PUBLIC_KEY")

# %% [markdown]
# ---
#
# ## Plaid Access Token
#
# In this section, you will use the `plaid-python` API to generate the correct authentication tokens to access data in the free developer Sandbox. This mimics how you might connect to your own account or a customer account, but due to privacy issues, this homework will only require connecting to and analyzing the fake data from the developer sandbox that Plaid provides.
#
# Complete the following steps to generate an access token:
#
# 1. Create a client to connect to plaid
#
# 2. Use the client to generate a public token and request the following items: ['transactions', 'income', 'assets']
#
# 3. Exchange the public token for an access token
#
# 4. Test the access token by requesting and printing the available test accounts

# %% [markdown]
# ### 1. Create a client to connect to plaid

# %%
# Create the client object
client = plaid.Client(
    client_id=PLAID_CLIENT_ID,
    secret=PLAID_SECRET,
    public_key=PLAID_PUBLIC_KEY,
    environment="sandbox"
)

# %%
# Set the institution id
INSITUTION_ID = "ins_109508"

# %% [markdown]
# ### 2. Generate a public token

# %%
# Create the public token
create_tkn_response = client.Sandbox.public_token.create(
    INSITUTION_ID,
    ["transactions","income","assets"]
)
# Print the public token
create_tkn_response
# Out:
# {'public_token': 'public-sandbox-7745de56-8574-4042-823e-69f558565285',
#  'request_id': 'nWyRwric6RIVIgd'}

# %% [markdown]
# ### 3. Exchange the public token for an access token

# %%
# Retrieve the access token
exchange_response = client.Item.public_token.exchange(create_tkn_response["public_token"])

# Print the access toke
exchange_response["access_token"]
# Out:
# 'access-sandbox-7e8aaf81-e1d7-4ded-a0e3-8b62d0a8507e'

# %%
# Store the access token in a Python variable
access_token = exchange_response["access_token"]

# %% [markdown]
# ### 4. Fetch Accounts

# %%
# Retrieve accounts
client_accounts = client.Accounts.get(access_token)
# Print accounts
client_accounts
# Out:
# {'accounts': [{'account_id': 'wZWKWAaRBlsBKdLxRmQliDbMZGwWoLurJk3wq',
#    'balances': {'available': 100,
#     'current': 110,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '0000',
#    'name': 'Plaid Checking',
#    'official_name': 'Plaid Gold Standard 0% Interest Checking',
#    'subtype': 'checking',
#    'type': 'depository'},
#   {'account_id': '58vovxenZbSQ36eJVgk8fKdvVP3yrguZ9Rblp',
#    'balances': {'available': 200,
#     'current': 210,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '1111',
#    'name': 'Plaid Saving',
#    'official_name': 'Plaid Silver Standard 0.1% Interest Saving',
#    'subtype': 'savings',
#    'type': 'depository'},
#   {'account_id': 'JXMEMalwPxTWzjn86BM3cZjm97vNRaCdma13Z',
#    'balances': {'available': None,
#     'current': 1000,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '2222',
#    'name': 'Plaid CD',
#    'official_name': 'Plaid Bronze Standard 0.2% Interest CD',
#    'subtype': 'cd',
#    'type': 'depository'},
#   {'account_id': 'kB7y7b9M1DUR8DJGmpeXhwGWlrnzkMFWkNqnq',
#    'balances': {'available': None,
#     'current': 410,
#     'iso_currency_code': 'USD',
#     'limit': 2000,
#     'unofficial_currency_code': None},
#    'mask': '3333',
#    'name': 'Plaid Credit Card',
#    'official_name': 'Plaid Diamond 12.5% APR Interest Credit Card',
#    'subtype': 'credit card',
#    'type': 'credit'},
#   {'account_id': 'l3eZeWvmLDfyewJxq79WFw5PVkQjJ7FZljnQM',
#    'balances': {'available': 43200,
#     'current': 43200,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '4444',
#    'name': 'Plaid Money Market',
#    'official_name': 'Plaid Platinum Standard 1.85% Interest Money Market',
#    'subtype': 'money market',
#    'type': 'depository'},
#   {'account_id': 'qkLRLXrJEDfyVDKXb6N9FVzD1l8Z7Lfdn9LGx',
#    'balances': {'available': None,
#     'current': 320.76,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '5555',
#    'name': 'Plaid IRA',
#    'official_name': None,
#    'subtype': 'ira',
#    'type': 'investment'},
#   {'account_id': 'KX1n1aqAjdTmlb3vkW1xta8LDrR3nXtVMeKqr',
#    'balances': {'available': None,
#     'current': 23631.9805,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '6666',
#    'name': 'Plaid 401k',
#    'official_name': None,
#    'subtype': '401k',
#    'type': 'investment'},
#   {'account_id': 'rPpJpRz7lDs1nbry9m7KiPepEw4nDBFlEjp4B',
#    'balances': {'available': None,
#     'current': 65262,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '7777',
#    'name': 'Plaid Student Loan',
#    'official_name': None,
#    'subtype': 'student',
#    'type': 'loan'},
#   {'account_id': 'zLkmkMPldrhnwjNzDLXEHP5LAVvxyDFopRMrJ',
#    'balances': {'available': None,
#     'current': 56302.06,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '8888',
#    'name': 'Plaid Mortgage',
#    'official_name': None,
#    'subtype': 'mortgage',
#    'type': 'loan'}],
#  'item': {'available_products': ['auth',
#    'balance',
#    'credit_details',
#    'identity',
#    'investments',
#    'liabilities'],
#   'billed_products': ['assets', 'income', 'transactions'],
#   'consent_expiration_time': None,
#   'error': None,
#   'institution_id': 'ins_109508',
#   'item_id': '6DRgRmQnM6sGxwLXJr8pFD7Gye5jP8igKAJvp',
#   'webhook': ''},
#  'request_id': 'RdII449RnerY0Tg'}

# %% [markdown]
# ---
#
# # Account Transactions with Plaid
#
# In this section, you will use the Plaid Python SDK to connect to the Developer Sandbox account and grab a list of transactions. You will need to complete the following steps:
#
#
# 1. Use the access token to fetch the transactions for the last 90 days
#
# 2. Print the categories for each transaction type
#
# 3. Create a new DataFrame using the following fields from the JSON transaction data: `date, name, amount, category`. (For categories with more than one label, just use the first category label in the list)
#
# 4. Convert the data types to the appropriate types (i.e. datetimeindex for the date and float for the amount)

# %% [markdown]
# ### 1. Fetch the Transactions for the last 90 days

# %%
# Set the start and end date 90 days from today
start_date = "{:%Y-%m-%d}".format(datetime.datetime.now() + datetime.timedelta(-90))
end_date = "{:%Y-%m-%d}".format(datetime.datetime.now())
# Retrieve the transactions for the last 90 days
transaction_response = client.Transactions.get(access_token,start_date,end_date)
# Print the transactions
pretty_print_response(transaction_response)
# Out:
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "xMArAB4D3qujRnNxqym6S73dnpoky6unK97K9",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "kB7y7b9M1DUR8DJGmpeXhwGWlrnzkMFWkNqnq",
#             "account_owner": null,
#             "amount": 2078.5,
#             "authorized_date": null,
#             "category": [
#                 "Payment"
#             ],
#             "category_id": "16000000",
#             "date": "2020-04-24",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "AUTOMATIC PAYMENT - THANK",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "35yKyBjnebUmezLGEj8otl4jJypG6VcqVwrVG",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "kB7y7b9M1DUR8DJGmpeXhwGWlrnzkMFWkNqnq",
#             "account_owner": null,
#             "amount": 500,
#             "authorized_date": null,
#             "category": [
#                 "Food and Drink",
#                 "Restaurants",
#                 "Fast Food"
#             ],
#             "category_id": "13005032",
#             "date": "2020-04-24",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "KFC",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "BX4R4lGLzZTKNvpAZw4GuXJdbW569Efwx7WxR",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "kB7y7b9M1DUR8DJGmpeXhwGWlrnzkMFWkNqnq",
#             "account_owner": null,
#             "amount": 500,
#             "authorized_date": null,
#             "category": [
#                 "Shops",
#                 "Sporting Goods"
#             ],
#             "category_id": "19046000",
#             "date": "2020-04-24",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "Madison Bicycle Shop",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "zLkmkMPldrhnwjNzDLXEHP5q9y6EVjfoXE7XK",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "58vovxenZbSQ36eJVgk8fKdvVP3yrguZ9Rblp",
#             "account_owner": null,
#             "amount": 25,
#             "authorized_date": null,
#             "category": [
#                 "Payment",
#                 "Credit Card"
#             ],
#             "category_id": "16001000",
#             "date": "2020-04-15",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "CREDIT CARD 3333 PAYMENT *//",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "dbxwxdWMPXS8JN1E6evyclMRGpd4qocZnPMeV",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "wZWKWAaRBlsBKdLxRmQliDbMZGwWoLurJk3wq",
#             "account_owner": null,
#             "amount": 5.4,
#             "authorized_date": null,
#             "category": [
#                 "Travel",
#                 "Taxi"
#             ],
#             "category_id": "22016000",
#             "date": "2020-04-15",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "Uber 063015 SF**POOL**",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "qkLRLXrJEDfyVDKXb6N9FVzbE73dl6idyJm1Q",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "l3eZeWvmLDfyewJxq79WFw5PVkQjJ7FZljnQM",
#             "account_owner": null,
#             "amount": 5850,
#             "authorized_date": null,
#             "category": [
#                 "Transfer",
#                 "Debit"
#             ],
#             "category_id": "21006000",
#             "date": "2020-04-14",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "ACH Electronic CreditGUSTO PAY 123456",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": "ACH",
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "RnW8WVdwLMTLxm38Var7TEjw4G638RURozlNk",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "JXMEMalwPxTWzjn86BM3cZjm97vNRaCdma13Z",
#             "account_owner": null,
#             "amount": 1000,
#             "authorized_date": null,
#             "category": [
#                 "Transfer",
#                 "Deposit"
#             ],
#             "category_id": "21007000",
#             "date": "2020-04-14",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "CD DEPOSIT .INITIAL.",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "y1GVG3NkxKSgdLPW6qp8c3zMVj6vB7cy8r3Xm",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "kB7y7b9M1DUR8DJGmpeXhwGWlrnzkMFWkNqnq",
#             "account_owner": null,
#             "amount": 78.5,
#             "authorized_date": null,
#             "category": [
#                 "Recreation",
#                 "Gyms and Fitness Centers"
#             ],
#             "category_id": "17018000",
#             "date": "2020-04-13",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "Touchstone Climbing",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "rPpJpRz7lDs1nbry9m7KiPexQDd8wzflkyPkz",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "wZWKWAaRBlsBKdLxRmQliDbMZGwWoLurJk3wq",
#             "account_owner": null,
#             "amount": -500,
#             "authorized_date": null,
#             "category": [
#                 "Travel",
#                 "Airlines and Aviation Services"
#             ],
#             "category_id": "22001000",
#             "date": "2020-04-13",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "United Airlines",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "l3eZeWvmLDfyewJxq79WFw5q4JL6kMHZmLwen",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "wZWKWAaRBlsBKdLxRmQliDbMZGwWoLurJk3wq",
#             "account_owner": null,
#             "amount": 12,
#             "authorized_date": null,
#             "category": [
#                 "Food and Drink",
#                 "Restaurants",
#                 "Fast Food"
#             ],
#             "category_id": "13005032",
#             "date": "2020-04-12",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": "3322"
#             },
#             "name": "McDonald's",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "JXMEMalwPxTWzjn86BM3cZjX5Reo7pCdeb4v5",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "wZWKWAaRBlsBKdLxRmQliDbMZGwWoLurJk3wq",
#             "account_owner": null,
#             "amount": 4.33,
#             "authorized_date": null,
#             "category": [
#                 "Food and Drink",
#                 "Restaurants",
#                 "Coffee Shop"
#             ],
#             "category_id": "13005043",
#             "date": "2020-04-12",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "Starbucks",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "kB7y7b9M1DUR8DJGmpeXhwGm9kpKrEHW1xQew",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "wZWKWAaRBlsBKdLxRmQliDbMZGwWoLurJk3wq",
#             "account_owner": null,
#             "amount": 89.4,
#             "authorized_date": null,
#             "category": [
#                 "Food and Drink",
#                 "Restaurants"
#             ],
#             "category_id": "13005000",
#             "date": "2020-04-11",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "SparkFun",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "58vovxenZbSQ36eJVgk8fKdZArEJPGIZQxwA3",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "58vovxenZbSQ36eJVgk8fKdvVP3yrguZ9Rblp",
#             "account_owner": null,
#             "amount": -4.22,
#             "authorized_date": null,
#             "category": [
#                 "Transfer",
#                 "Credit"
#             ],
#             "category_id": "21005000",
#             "date": "2020-04-10",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "INTRST PYMNT",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "xMArAB4D3qujRnNxqym6S73dnpoky6unK97vd",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "kB7y7b9M1DUR8DJGmpeXhwGWlrnzkMFWkNqnq",
#             "account_owner": null,
#             "amount": 500,
#             "authorized_date": null,
#             "category": [
#                 "Travel",
#                 "Airlines and Aviation Services"
#             ],
#             "category_id": "22001000",
#             "date": "2020-03-31",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "United Airlines",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "KX1n1aqAjdTmlb3vkW1xta8o6nqbrksVD6ZDq",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         }
#     ]
# }

# %% [markdown]
# ### 2. Print the categories for each transaction

# %%
# Create a for-loop to print the categories for each transaction
for transaction in transaction_response['transactions']:
    print(transaction['category'])
# Out:
# ['Travel', 'Airlines and Aviation Services']
# ['Travel', 'Taxi']
# ['Food and Drink', 'Restaurants']
# ['Payment']
# ['Food and Drink', 'Restaurants', 'Fast Food']
# ['Shops', 'Sporting Goods']
# ['Payment', 'Credit Card']
# ['Travel', 'Taxi']
# ['Transfer', 'Debit']
# ['Transfer', 'Deposit']
# ['Recreation', 'Gyms and Fitness Centers']
# ['Travel', 'Airlines and Aviation Services']
# ['Food and Drink', 'Restaurants', 'Fast Food']
# ['Food and Drink', 'Restaurants', 'Coffee Shop']
# ['Food and Drink', 'Restaurants']
# ['Transfer', 'Credit']
# ['Travel', 'Airlines and Aviation Services']
# ['Travel', 'Taxi']
# ['Food and Drink', 'Restaurants']
# ['Payment']
# ['Food and Drink', 'Restaurants', 'Fast Food']
# ['Shops', 'Sporting Goods']
# ['Payment', 'Credit Card']
# ['Travel', 'Taxi']
# ['Transfer', 'Debit']
# ['Transfer', 'Deposit']
# ['Recreation', 'Gyms and Fitness Centers']
# ['Travel', 'Airlines and Aviation Services']
# ['Food and Drink', 'Restaurants', 'Fast Food']
# ['Food and Drink', 'Restaurants', 'Coffee Shop']
# ['Food and Drink', 'Restaurants']
# ['Transfer', 'Credit']
# ['Travel', 'Airlines and Aviation Services']
# ['Travel', 'Taxi']
# ['Food and Drink', 'Restaurants']
# ['Payment']
# ['Food and Drink', 'Restaurants', 'Fast Food']
# ['Shops', 'Sporting Goods']
# ['Payment', 'Credit Card']
# ['Travel', 'Taxi']
# ['Transfer', 'Debit']
# ['Transfer', 'Deposit']
# ['Recreation', 'Gyms and Fitness Centers']
# ['Travel', 'Airlines and Aviation Services']
# ['Food and Drink', 'Restaurants', 'Fast Food']
# ['Food and Drink', 'Restaurants', 'Coffee Shop']
# ['Food and Drink', 'Restaurants']
# ['Transfer', 'Credit']
# ['Travel', 'Airlines and Aviation Services']

# %% [markdown]
# ### 3. Create a new DataFrame using the following fields from the JSON transaction data: `date`, `name`, `amount`, `category`.
#
# (For categories with more than one label, just use the first category label in the list)

# %%
# Define an empty DataFrame and set the columns as date, name, amount, and category
transaction_df = pd.DataFrame()
date = []
name = []
amount = []
category = []
# Retrieve all the transactions
for transaction in transaction_response['transactions']:
# Populate the transactions DataFrame with the transactions data
    date.append(transaction['date'])
    name.append(transaction['name'])
    amount.append(transaction['amount'])
    category.append(transaction['category'][0])
transaction_df['date'] = date
transaction_df['name'] = name
transaction_df['amount'] = amount
transaction_df['category'] = category
# Display sample data from the DataFrame  

transaction_df
# Out:
#           date                                   name   amount        category
# 0   2020-06-29                        United Airlines   500.00          Travel
# 1   2020-06-27                 Uber 072515 SF**POOL**     6.33          Travel
# 2   2020-06-24                             Tectra Inc   500.00  Food and Drink
# 3   2020-06-23              AUTOMATIC PAYMENT - THANK  2078.50         Payment
# 4   2020-06-23                                    KFC   500.00  Food and Drink
# 5   2020-06-23                   Madison Bicycle Shop   500.00           Shops
# 6   2020-06-14           CREDIT CARD 3333 PAYMENT *//    25.00         Payment
# 7   2020-06-14                 Uber 063015 SF**POOL**     5.40          Travel
# 8   2020-06-13  ACH Electronic CreditGUSTO PAY 123456  5850.00        Transfer
# 9   2020-06-13                   CD DEPOSIT .INITIAL.  1000.00        Transfer
# 10  2020-06-12                    Touchstone Climbing    78.50      Recreation
# 11  2020-06-12                        United Airlines  -500.00          Travel
# 12  2020-06-11                             McDonald's    12.00  Food and Drink
# 13  2020-06-11                              Starbucks     4.33  Food and Drink
# 14  2020-06-10                               SparkFun    89.40  Food and Drink
# 15  2020-06-09                           INTRST PYMNT    -4.22        Transfer
# 16  2020-05-30                        United Airlines   500.00          Travel
# 17  2020-05-28                 Uber 072515 SF**POOL**     6.33          Travel
# 18  2020-05-25                             Tectra Inc   500.00  Food and Drink
# 19  2020-05-24              AUTOMATIC PAYMENT - THANK  2078.50         Payment
# 20  2020-05-24                                    KFC   500.00  Food and Drink
# 21  2020-05-24                   Madison Bicycle Shop   500.00           Shops
# 22  2020-05-15           CREDIT CARD 3333 PAYMENT *//    25.00         Payment
# 23  2020-05-15                 Uber 063015 SF**POOL**     5.40          Travel
# 24  2020-05-14  ACH Electronic CreditGUSTO PAY 123456  5850.00        Transfer
# 25  2020-05-14                   CD DEPOSIT .INITIAL.  1000.00        Transfer
# 26  2020-05-13                    Touchstone Climbing    78.50      Recreation
# 27  2020-05-13                        United Airlines  -500.00          Travel
# 28  2020-05-12                             McDonald's    12.00  Food and Drink
# 29  2020-05-12                              Starbucks     4.33  Food and Drink
# 30  2020-05-11                               SparkFun    89.40  Food and Drink
# 31  2020-05-10                           INTRST PYMNT    -4.22        Transfer
# 32  2020-04-30                        United Airlines   500.00          Travel
# 33  2020-04-28                 Uber 072515 SF**POOL**     6.33          Travel
# 34  2020-04-25                             Tectra Inc   500.00  Food and Drink
# 35  2020-04-24              AUTOMATIC PAYMENT - THANK  2078.50         Payment
# 36  2020-04-24                                    KFC   500.00  Food and Drink
# 37  2020-04-24                   Madison Bicycle Shop   500.00           Shops
# 38  2020-04-15           CREDIT CARD 3333 PAYMENT *//    25.00         Payment
# 39  2020-04-15                 Uber 063015 SF**POOL**     5.40          Travel
# 40  2020-04-14  ACH Electronic CreditGUSTO PAY 123456  5850.00        Transfer
# 41  2020-04-14                   CD DEPOSIT .INITIAL.  1000.00        Transfer
# 42  2020-04-13                    Touchstone Climbing    78.50      Recreation
# 43  2020-04-13                        United Airlines  -500.00          Travel
# 44  2020-04-12                             McDonald's    12.00  Food and Drink
# 45  2020-04-12                              Starbucks     4.33  Food and Drink
# 46  2020-04-11                               SparkFun    89.40  Food and Drink
# 47  2020-04-10                           INTRST PYMNT    -4.22        Transfer
# 48  2020-03-31                        United Airlines   500.00          Travel

# %% [markdown]
# ### 4. Convert the data types to the appropriate types
#
# (i.e. datetimeindex for the date and float for the amount)

# %%
# Display data types
transaction_df.dtypes
# Out:
# date         object
# name         object
# amount      float64
# category     object
# dtype: object

# %%
# Make any required data type transformation
transaction_df["date"] = pd.to_datetime(transaction_df["date"], infer_datetime_format=True)
transaction_df.dtypes
# Out:
# date        datetime64[ns]
# name                object
# amount             float64
# category            object
# dtype: object

# %%
# Set the date column as index
transaction_df = transaction_df.set_index(transaction_df["date"])
transaction_df = transaction_df.drop(columns=["date"])
# Display sample data
transaction_df
# Out:
#                                              name   amount        category
# date
# 2020-06-29                        United Airlines   500.00          Travel
# 2020-06-27                 Uber 072515 SF**POOL**     6.33          Travel
# 2020-06-24                             Tectra Inc   500.00  Food and Drink
# 2020-06-23              AUTOMATIC PAYMENT - THANK  2078.50         Payment
# 2020-06-23                                    KFC   500.00  Food and Drink
# 2020-06-23                   Madison Bicycle Shop   500.00           Shops
# 2020-06-14           CREDIT CARD 3333 PAYMENT *//    25.00         Payment
# 2020-06-14                 Uber 063015 SF**POOL**     5.40          Travel
# 2020-06-13  ACH Electronic CreditGUSTO PAY 123456  5850.00        Transfer
# 2020-06-13                   CD DEPOSIT .INITIAL.  1000.00        Transfer
# 2020-06-12                    Touchstone Climbing    78.50      Recreation
# 2020-06-12                        United Airlines  -500.00          Travel
# 2020-06-11                             McDonald's    12.00  Food and Drink
# 2020-06-11                              Starbucks     4.33  Food and Drink
# 2020-06-10                               SparkFun    89.40  Food and Drink
# 2020-06-09                           INTRST PYMNT    -4.22        Transfer
# 2020-05-30                        United Airlines   500.00          Travel
# 2020-05-28                 Uber 072515 SF**POOL**     6.33          Travel
# 2020-05-25                             Tectra Inc   500.00  Food and Drink
# 2020-05-24              AUTOMATIC PAYMENT - THANK  2078.50         Payment
# 2020-05-24                                    KFC   500.00  Food and Drink
# 2020-05-24                   Madison Bicycle Shop   500.00           Shops
# 2020-05-15           CREDIT CARD 3333 PAYMENT *//    25.00         Payment
# 2020-05-15                 Uber 063015 SF**POOL**     5.40          Travel
# 2020-05-14  ACH Electronic CreditGUSTO PAY 123456  5850.00        Transfer
# 2020-05-14                   CD DEPOSIT .INITIAL.  1000.00        Transfer
# 2020-05-13                    Touchstone Climbing    78.50      Recreation
# 2020-05-13                        United Airlines  -500.00          Travel
# 2020-05-12                             McDonald's    12.00  Food and Drink
# 2020-05-12                              Starbucks     4.33  Food and Drink
# 2020-05-11                               SparkFun    89.40  Food and Drink
# 2020-05-10                           INTRST PYMNT    -4.22        Transfer
# 2020-04-30                        United Airlines   500.00          Travel
# 2020-04-28                 Uber 072515 SF**POOL**     6.33          Travel
# 2020-04-25                             Tectra Inc   500.00  Food and Drink
# 2020-04-24              AUTOMATIC PAYMENT - THANK  2078.50         Payment
# 2020-04-24                                    KFC   500.00  Food and Drink
# 2020-04-24                   Madison Bicycle Shop   500.00           Shops
# 2020-04-15           CREDIT CARD 3333 PAYMENT *//    25.00         Payment
# 2020-04-15                 Uber 063015 SF**POOL**     5.40          Travel
# 2020-04-14  ACH Electronic CreditGUSTO PAY 123456  5850.00        Transfer
# 2020-04-14                   CD DEPOSIT .INITIAL.  1000.00        Transfer
# 2020-04-13                    Touchstone Climbing    78.50      Recreation
# 2020-04-13                        United Airlines  -500.00          Travel
# 2020-04-12                             McDonald's    12.00  Food and Drink
# 2020-04-12                              Starbucks     4.33  Food and Drink
# 2020-04-11                               SparkFun    89.40  Food and Drink
# 2020-04-10                           INTRST PYMNT    -4.22        Transfer
# 2020-03-31                        United Airlines   500.00          Travel

# %% [markdown]
# ---

# %% [markdown]
# # Income Analysis with Plaid
#
# In this section, you will use the Plaid Sandbox to complete the following:
#
# 1. Determine the previous year's gross income and print the results
#
# 2. Determine the current monthly income and print the results
#
# 3. Determine the projected yearly income and print the results

# %%
# Fetch the income data
income_response = client.Income.get(access_token)
# Print the income data
pretty_print_response(income_response)
# Out:
# {
#     "income": {
#         "income_streams": [
#             {
#                 "confidence": 0.99,
#                 "days": 690,
#                 "monthly_income": 500,
#                 "name": "UNITED AIRLINES"
#             }
#         ],
#         "last_year_income": 6000,
#         "last_year_income_before_tax": 7285,
#         "max_number_of_overlapping_income_streams": 1,
#         "number_of_income_streams": 1,
#         "projected_yearly_income": 6085,
#         "projected_yearly_income_before_tax": 7389
#     },
#     "request_id": "M2tkJBAwYe41KI8"
# }

# %%
# Determine the previous year's gross income and print the results
last_year_income = income_response['income']['last_year_income']
last_year_income
# Out:
# 6000

# %%
# Determine the current monthly income and print the results
monthly_income = income_response['income']['income_streams'][0]['monthly_income']
monthly_income
# Out:
# 500

# %%
# Determine the projected yearly income and print the results
projected_yearly_income = income_response['income']['projected_yearly_income']
projected_yearly_income
# Out:
# 6085

# %% [markdown]
# ---

# %% [markdown]
# # Budget Analysis
# In this section, you will use the transactions DataFrame to analyze the customer's budget
#
# 1. Calculate the total spending per category and print the results (Hint: groupby or count transactions per category)
#
# 2. Generate a bar chart with the number of transactions for each category
#
# 3. Calulate the expenses per month
#
# 4. Plot the total expenses per month

# %% [markdown]
# ### Calculate the expenses per category

# %%
# Compute the total expenses per category
expenses_per_category = transaction_df.groupby('category').sum()
# Display the expenses per catefory
expenses_per_category
# Out:
#                   amount
# category
# Food and Drink   3317.19
# Payment          6310.50
# Recreation        235.50
# Shops            1500.00
# Transfer        20537.34
# Travel            535.19

# %%
# Create a spending categories pie chart.
expenses_per_category.plot.pie(y='amount', figsize=(10, 10))

# %% [markdown]
# ### Calculate the expenses per month

# %%
# Create a DataFrame with the total expenses
expenses_per_month = transaction_df.groupby(transaction_df.index.month).sum()
# Display sample data
expenses_per_month
# Out:
#         amount
# date
# 3       500.00
# 4     10645.24
# 5     10645.24
# 6     10645.24

# %%
# Create a spending per month bar chart
expenses_per_month.plot.bar()
